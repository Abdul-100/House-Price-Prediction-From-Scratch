# %%
import numpy as np
data_x = np.array([1000, 2000, 3000, 4000, 5000, 6000])
predict_y = np.array([200, 300, 400, 500, 600, 700])
weight = 0.1
bias = 10
learning_rate = 0.00000001
for epoch in range(10):
  predicted_y = weight * data_x + bias
  loss = np.mean((predicted_y - predict_y) **2 )
  w_gradient = -2 * np.mean(data_x * (predict_y - predicted_y))
  weight = weight - learning_rate * w_gradient
  b_gradient = -2 * np.mean(price_y - y_pred)
  bias = bias - (0.1 * b_gradient)
  print(f"Epoch {epoch+1}: Weight is {weight:.4f}, Loss is {loss:.2f}")
# Out:
# Epoch 1: Weight is 0.1063, Loss is 8100.00
# Epoch 2: Weight is 0.1104, Loss is 4202.35
# Epoch 3: Weight is 0.1130, Loss is 2388.64
# Epoch 4: Weight is 0.1145, Loss is 1546.52
# Epoch 5: Weight is 0.1153, Loss is 1149.21
# Epoch 6: Weight is 0.1155, Loss is 950.09
# Epoch 7: Weight is 0.1154, Loss is 835.83
# Epoch 8: Weight is 0.1151, Loss is 755.82
# Epoch 9: Weight is 0.1146, Loss is 688.58
# Epoch 10: Weight is 0.1139, Loss is 625.82
